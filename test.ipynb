# %%
import pandas as pd

# %%
pd.DataFrame(range(100)).rolling(window=5, closed="both").mean()
# Out:
#        0
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    2.0
# ..   ...
# 95  92.5
# 96  93.5
# 97  94.5
# 98  95.5
# 99  96.5
#
# [100 rows x 1 columns]
