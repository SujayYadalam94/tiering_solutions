# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DuckDB-TPCH-sf100.log")

# %%
list(df.columns)
# Out:
# ['step',
#  'page',
#  'read',
#  'write',
#  'count',
#  'malloc_size',
#  'ewma_2',
#  'ewma_5',
#  'ewma_20',
#  'ewma_100',
#  'ewma_2_r',
#  'ewma_5_r',
#  'ewma_20_r',
#  'ewma_100_r',
#  'ewma_2_w',
#  'ewma_5_w',
#  'ewma_20_w',
#  'ewma_100_w',
#  'ewma_2_perc',
#  'ewma_5_perc',
#  'ewma_20_perc',
#  'ewma_100_perc',
#  'ewma_2_r_perc',
#  'ewma_5_r_perc',
#  'ewma_20_r_perc',
#  'ewma_100_r_perc',
#  'ewma_2_w_perc',
#  'ewma_5_w_perc',
#  'ewma_20_w_perc',
#  'ewma_100_w_perc',
#  'ewma_2_malloc_size',
#  'ewma_5_malloc_size',
#  'ewma_20_malloc_size',
#  'ewma_100_malloc_size',
#  'ewma_2_malloc_calls',
#  'ewma_5_malloc_calls',
#  'ewma_20_malloc_calls',
#  'ewma_100_malloc_calls',
#  'global_count_since_top1_percent_ewma5',
#  'global_count_since_top50_percent_ewma5',
#  'rank',
#  'rank_perc',
#  'rank_ewma_2',
#  'rank_ewma_5',
#  'rank_ewma_20',
#  'rank_ewma_100',
#  'count_total',
#  'global_count_similar',
#  'diff',
#  'cpu_usage',
#  'disk_read_bytes',
#  'disk_write_bytes',
#  'syscr',
#  'syscw',
#  'age',
#  'age_count_total',
#  'group_-7_mean',
#  'group_-7_mean_perc',
#  'group_-7_mean_ewma5',
#  'group_-7_mean_ewma5_perc',
#  'group_-6_mean',
#  'group_-6_mean_perc',
#  'group_-6_mean_ewma5',
#  'group_-6_mean_ewma5_perc',
#  'group_-5_mean',
#  'group_-5_mean_perc',
#  'group_-5_mean_ewma5',
#  'group_-5_mean_ewma5_perc',
#  'group_-4_mean',
#  'group_-4_mean_perc',
#  'group_-4_mean_ewma5',
#  'group_-4_mean_ewma5_perc',
#  'group_-3_mean',
#  'group_-3_mean_perc',
#  'group_-3_mean_ewma5',
#  'group_-3_mean_ewma5_perc',
#  'group_-2_mean',
#  'group_-2_mean_perc',
#  'group_-2_mean_ewma5',
#  'group_-2_mean_ewma5_perc',
#  'group_-1_mean',
#  'group_-1_mean_perc',
#  'group_-1_mean_ewma5',
#  'group_-1_mean_ewma5_perc',
#  'group_0_mean',
#  'group_0_mean_perc',
#  'group_0_mean_ewma5',
#  'group_0_mean_ewma5_perc',
#  'group_1_mean',
#  'group_1_mean_perc',
#  'group_1_mean_ewma5',
#  'group_1_mean_ewma5_perc',
#  'group_2_mean',
#  'group_2_mean_perc',
#  'group_2_mean_ewma5',
#  'group_2_mean_ewma5_perc',
#  'group_3_mean',
#  'group_3_mean_perc',
#  'group_3_mean_ewma5',
#  'group_3_mean_ewma5_perc',
#  'group_4_mean',
#  'group_4_mean_perc',
#  'group_4_mean_ewma5',
#  'group_4_mean_ewma5_perc',
#  'group_5_mean',
#  'group_5_mean_perc',
#  'group_5_mean_ewma5',
#  'group_5_mean_ewma5_perc',
#  'group_6_mean',
#  'group_6_mean_perc',
#  'group_6_mean_ewma5',
#  'group_6_mean_ewma5_perc',
#  'group_7_mean',
#  'group_7_mean_perc',
#  'group_7_mean_ewma5',
#  'group_7_mean_ewma5_perc',
#  'model_selection',
#  'model_score',
#  'arms_score',
#  'in_dram',
#  'read_syscalls',
#  'write_syscalls',
#  'read_bytes',
#  'write_bytes',
#  'sum_malloc_bytes',
#  'min_malloc_bytes',
#  'max_malloc_bytes',
#  'malloc_call',
#  'discounted_reward_90',
#  'discounted_reward_95',
#  'discounted_reward_99',
#  'Unnamed: 131']

# %%
import matplotlib.colors

for col in [
    #"count",
    #"ewma_2",
    #"ewma_5",
    #"ewma_20",
    #"ewma_100",
    #"global_count_since_top50_percent_ewma5",
    #"group_-3_mean_ewma5_perc",
    #"group_-2_mean_ewma5_perc",
    #"group_-1_mean_ewma5_perc",
    #"group_-3_mean_ewma5_perc",
    #"group_0_mean_ewma5_perc",
    #"group_1_mean_ewma5_perc",
    #"group_2_mean_ewma5_perc",
    #"group_3_mean_ewma5_perc",
    #"age_count_total",
    #"ewma_100_malloc_calls"
    "age",
    "discounted_reward_90",
    "discounted_reward_95",
    "discounted_reward_99",
]:
    pivot_df = df.pivot(index="page", columns="step", values=col)
    sns.heatmap(pivot_df, cmap="YlOrRd", annot=False, norm=matplotlib.colors.LogNorm()).set(title=col)
    plt.show()
